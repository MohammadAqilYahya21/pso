# %% [markdown]
# # meta - PSO
#
# This modified code implements PSO for the multiple knapsack problem. Here are the key changes and additions:
#
# A new Particle class is introduced to represent each particle in the swarm.
# The particle_swarm_optimization function replaces the simulated_annealing function. It initializes a swarm of particles and iteratively updates their positions and velocities.
# Each particle's position is represented as a list of integers, where each integer corresponds to the knapsack index for each item. A value equal to the number of knapsacks means the item is not selected.
# The particle's velocity is used to update its position, with cognitive and social components influencing the movement.
# The global best solution is tracked and updated throughout the iterations.
# The main PSO parameters (w, c1, c2) are set to common values, but you may want to tune these for your specific problem.
# The main function now calls particle_swarm_optimization instead of simulated_annealing.
#
# This PSO implementation should provide good results for the multiple knapsack problem, potentially exploring the solution space more effectively than the previous Simulated Annealing approach. You may need to adjust the number of particles and iterations to balance between solution quality and computation time.

# %%
import random
import math
import pandas as pd
import numpy as np

# Item and Knapsack classes remain the same

# Define the problem function remains the same

# Particle class for PSO
class Particle:
    def __init__(self, items, knapsacks):
        self.position = [random.choice(range(len(knapsacks) + 1)) for _ in items]
        self.velocity = [random.uniform(-1, 1) for _ in items]
        self.best_position = self.position[:]
        self.best_value = self.evaluate(items, knapsacks)

    def evaluate(self, items, knapsacks):
        solution = [Knapsack(k.capacity, k.budget) for k in knapsacks]
        for i, knapsack_index in enumerate(self.position):
            if knapsack_index < len(knapsacks):
                solution[knapsack_index].add_item(items[i])
        return sum(k.total_value() for k in solution) if all(k.is_valid() for k in solution) else 0

    def update_velocity(self, global_best_position, w, c1, c2):
        for i in range(len(self.velocity)):
            r1, r2 = random.random(), random.random()
            cognitive = c1 * r1 * (self.best_position[i] - self.position[i])
            social = c2 * r2 * (global_best_position[i] - self.position[i])
            self.velocity[i] = w * self.velocity[i] + cognitive + social

    def update_position(self, num_knapsacks):
        for i in range(len(self.position)):
            self.position[i] = max(0, min(num_knapsacks, round(self.position[i] + self.velocity[i])))

# PSO algorithm
def particle_swarm_optimization(items, knapsacks, num_particles, num_iterations):
    particles = [Particle(items, knapsacks) for _ in range(num_particles)]
    global_best_position = particles[0].position[:]
    global_best_value = particles[0].best_value

    w, c1, c2 = 0.7, 1.4, 1.4  # PSO parameters

    for _ in range(num_iterations):
        for particle in particles:
            value = particle.evaluate(items, knapsacks)
            if value > particle.best_value:
                particle.best_value = value
                particle.best_position = particle.position[:]
            if value > global_best_value:
                global_best_value = value
                global_best_position = particle.position[:]

        for particle in particles:
            particle.update_velocity(global_best_position, w, c1, c2)
            particle.update_position(len(knapsacks))

    # Convert the best position to a solution
    best_solution = [Knapsack(k.capacity, k.budget) for k in knapsacks]
    for i, knapsack_index in enumerate(global_best_position):
        if knapsack_index < len(knapsacks):
            best_solution[knapsack_index].add_item(items[i])

    return best_solution, global_best_value

# The evaluate_solution function remains the same

def main():
    dataset_csv = 'product_data.csv'
    bin_csv = 'bin.csv'
    items, knapsacks = create_problem(dataset_csv, bin_csv)
    
    num_particles = 50
    num_iterations = 1000

    best_solution, best_value = particle_swarm_optimization(items, knapsacks, num_particles, num_iterations)

    print(f"Best value found: {best_value}")
    for i, knapsack in enumerate(best_solution):
        print(f"\nKnapsack {i+1}:")
        print(f"Total weight: {knapsack.total_weight():.2f}/{knapsack.capacity}")
        print(f"Total price: {knapsack.total_price():.2f}/{knapsack.budget}")
        print("Items:")
        for item in knapsack.items:
            print(f"  {item.category} - {item.name}: weight={item.weight:.2f}, value={item.value:.2f}, price={item.price:.2f}")
    
    print("\nEvaluating solution:")
    total_value, all_constraints_met = evaluate_solution(best_solution, knapsacks)
    print(f"Total value: {total_value:.2f}")
    print(f"All constraints met: {'Yes' if all_constraints_met else 'No'}")

if __name__ == "__main__":
    main()
# Out:
# Best value found: 3852.9400000000005
#
# Knapsack 1:
# Total weight: 49.83/50
# Total price: 453.59/500
# Items:
#   Preserved Vegetables - Product G: weight=1.68, value=39.47, price=24.15
#   Sweet Pastries - Product C: weight=2.81, value=20.02, price=25.89
#   Beverages - Product C: weight=1.36, value=6.02, price=21.62
#   Preserved Vegetables - Product C: weight=0.50, value=3.36, price=11.11
#   Preserved Vegetables - Product E: weight=0.13, value=92.69, price=3.79
#   Sweet Pastries - Product C: weight=3.18, value=56.06, price=28.28
#   Beverages - Product E: weight=0.45, value=38.16, price=16.01
#   Traditional Snacks - Product J: weight=2.25, value=7.51, price=21.18
#   Dried Seafood - Product D: weight=4.21, value=6.71, price=8.56
#   Savory Pastries - Product G: weight=0.29, value=8.21, price=17.19
#   Canned Fruits - Product J: weight=3.53, value=32.57, price=23.77
#   Beverages - Product A: weight=0.30, value=135.60, price=29.24
#   Dried Fruits - Product I: weight=2.05, value=54.75, price=9.23
#   Sweet Pastries - Product C: weight=1.00, value=65.90, price=29.84
#   Spices - Product C: weight=1.27, value=55.34, price=21.91
#   Spices - Product J: weight=0.56, value=89.26, price=9.93
#   Savory Pastries - Product F: weight=4.68, value=116.55, price=15.76
#   Dried Seafood - Product A: weight=3.68, value=2.81, price=15.12
#   Savory Pastries - Product J: weight=0.33, value=10.07, price=27.28
#   Sauces - Product G: weight=2.38, value=114.62, price=26.62
#   Traditional Snacks - Product A: weight=4.75, value=38.70, price=10.59
#   Preserved Vegetables - Product B: weight=1.38, value=28.35, price=17.60
#   Sauces - Product D: weight=3.42, value=75.16, price=7.06
#   Canned Fruits - Product B: weight=2.91, value=100.56, price=20.46
#   Preserved Vegetables - Product F: weight=0.73, value=102.19, price=11.40
#
# Knapsack 2:
# Total weight: 74.25/75
# Total price: 574.82/750
# Items:
#   Sauces - Product B: weight=1.35, value=84.29, price=12.57
#   Beverages - Product G: weight=4.26, value=60.51, price=5.37
#   Dried Fruits - Product J: weight=2.04, value=4.02, price=25.29
#   Preserved Vegetables - Product G: weight=0.35, value=14.07, price=20.60
#   Dried Fruits - Product I: weight=0.24, value=17.13, price=7.06
#   Beverages - Product J: weight=2.94, value=140.24, price=16.70
#   Sweet Pastries - Product E: weight=4.32, value=35.99, price=29.89
#   Canned Fruits - Product D: weight=1.59, value=7.68, price=26.60
#   Sweet Pastries - Product G: weight=2.73, value=58.32, price=6.47
#   Sauces - Product B: weight=1.43, value=11.11, price=25.55
#   Beverages - Product J: weight=4.83, value=38.65, price=25.83
#   Canned Fruits - Product I: weight=2.34, value=30.85, price=12.73
#   Dried Fruits - Product F: weight=1.05, value=3.09, price=25.68
#   Dried Fruits - Product G: weight=0.78, value=37.56, price=20.40
#   Dried Seafood - Product I: weight=0.75, value=13.75, price=17.84
#   Sauces - Product D: weight=3.75, value=132.35, price=15.08
#   Traditional Snacks - Product G: weight=0.50, value=42.88, price=6.10
#   Savory Pastries - Product F: weight=2.20, value=3.10, price=1.52
#   Preserved Vegetables - Product I: weight=0.39, value=72.23, price=6.19
#   Dried Fruits - Product A: weight=2.27, value=35.33, price=22.58
#   Dried Seafood - Product H: weight=1.00, value=8.69, price=16.73
#   Dried Fruits - Product A: weight=2.23, value=16.91, price=29.39
#   Preserved Vegetables - Product D: weight=2.87, value=101.51, price=13.60
#   Canned Fruits - Product B: weight=0.69, value=95.39, price=19.71
#   Preserved Vegetables - Product C: weight=1.78, value=119.57, price=20.40
#   Beverages - Product A: weight=1.63, value=28.40, price=15.48
#   Dried Seafood - Product A: weight=0.96, value=34.42, price=23.29
#   Traditional Snacks - Product B: weight=4.05, value=11.23, price=14.63
#   Preserved Vegetables - Product C: weight=4.44, value=3.79, price=17.03
#   Sweet Pastries - Product E: weight=0.17, value=52.41, price=29.43
#   Traditional Snacks - Product J: weight=4.67, value=62.47, price=3.19
#   Preserved Vegetables - Product F: weight=2.56, value=19.24, price=9.87
#   Sweet Pastries - Product G: weight=2.74, value=87.94, price=6.54
#   Sauces - Product F: weight=4.35, value=31.27, price=25.48
#
# Knapsack 3:
# Total weight: 49.95/50
# Total price: 284.17/600
# Items:
#   Sauces - Product H: weight=1.55, value=29.11, price=10.45
#   Preserved Vegetables - Product F: weight=2.16, value=58.41, price=7.39
#   Spices - Product A: weight=1.05, value=27.82, price=12.53
#   Spices - Product G: weight=4.44, value=24.52, price=22.32
#   Dried Seafood - Product C: weight=3.39, value=26.01, price=7.63
#   Spices - Product G: weight=1.71, value=107.86, price=6.07
#   Canned Fruits - Product A: weight=0.86, value=77.44, price=29.48
#   Beverages - Product C: weight=1.70, value=52.36, price=9.09
#   Savory Pastries - Product D: weight=2.12, value=24.26, price=28.13
#   Savory Pastries - Product I: weight=2.22, value=33.29, price=9.86
#   Spices - Product H: weight=3.23, value=84.50, price=19.45
#   Dried Seafood - Product D: weight=3.32, value=0.73, price=18.11
#   Sauces - Product G: weight=0.88, value=56.96, price=11.15
#   Beverages - Product A: weight=0.55, value=75.12, price=26.06
#   Dried Fruits - Product E: weight=0.56, value=48.86, price=7.68
#   Canned Fruits - Product E: weight=3.28, value=101.06, price=22.68
#   Sweet Pastries - Product D: weight=3.45, value=39.78, price=8.79
#   Beverages - Product H: weight=4.73, value=54.12, price=11.81
#   Dried Seafood - Product A: weight=4.73, value=24.99, price=12.45
#   Canned Fruits - Product E: weight=4.02, value=88.71, price=3.04
#
# Evaluating solution:
# Total value: 3852.94
# All constraints met: Yes
